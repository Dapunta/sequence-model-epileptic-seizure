# %% [markdown]
# # Sequence Model
#
# |         |                               |
# | :------ | :---------------------------- |
# | Dataset | Epileptic Seizure Recognition |
# | Model   | RNN                           |

# %%
# ============================================================
# BLOK 1 - IMPORT LIBRARY
# ============================================================

import os
import json
import random
import warnings
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import (
    accuracy_score,
    balanced_accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    classification_report,
    confusion_matrix,
    roc_auc_score,
)

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, Model
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

warnings.filterwarnings("ignore")
plt.style.use("ggplot")
# Out:
# 2026-04-19 09:52:36.239857: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1776592356.480886      22 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1776592356.551545      22 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1776592357.103397      22 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776592357.103444      22 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776592357.103447      22 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776592357.103450      22 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.

# %% [markdown]
# ## Blok 1
#
# Mengimpor library utama untuk:
# - membaca dataset
# - preprocessing
# - membangun model TensorFlow
# - training
# - evaluasi
# - visualisasi hasil

# %%
# ============================================================
# BLOK 2 - KONFIGURASI
# ============================================================

SEED = 42
MODEL_NAME = "RNN"

VAL_SIZE = 0.15
TEST_SIZE = 0.15

BATCH_SIZE = 64
EPOCHS = 40
LEARNING_RATE = 1e-3

RNN_UNITS_1 = 128
RNN_UNITS_2 = 64
RNN_DROPOUT = 0.00
ATTN_HEADS = 4
ATTN_KEY_DIM = 32
ATTN_DROPOUT = 0.10
DENSE_UNITS = 128
DENSE_DROPOUT = 0.30

random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

print({
    "MODEL_NAME": MODEL_NAME,
    "VAL_SIZE": VAL_SIZE,
    "TEST_SIZE": TEST_SIZE,
    "BATCH_SIZE": BATCH_SIZE,
    "EPOCHS": EPOCHS,
    "LEARNING_RATE": LEARNING_RATE,
    "RNN_UNITS_1": RNN_UNITS_1,
    "RNN_UNITS_2": RNN_UNITS_2,
    "RNN_DROPOUT": RNN_DROPOUT,
    "ATTN_HEADS": ATTN_HEADS,
    "ATTN_KEY_DIM": ATTN_KEY_DIM,
    "ATTN_DROPOUT": ATTN_DROPOUT,
    "DENSE_UNITS": DENSE_UNITS,
    "DENSE_DROPOUT": DENSE_DROPOUT,
})
# Out:
# {'MODEL_NAME': 'RNN', 'VAL_SIZE': 0.15, 'TEST_SIZE': 0.15, 'BATCH_SIZE': 64, 'EPOCHS': 40, 'LEARNING_RATE': 0.001, 'RNN_UNITS_1': 128, 'RNN_UNITS_2': 64, 'RNN_DROPOUT': 0.0, 'ATTN_HEADS': 4, 'ATTN_KEY_DIM': 32, 'ATTN_DROPOUT': 0.1, 'DENSE_UNITS': 128, 'DENSE_DROPOUT': 0.3}

# %% [markdown]
# ## Blok 2
# Menentukan parameter eksperimen
#
# Konfigurasi model:
# - vanilla recurrent cell bertingkat
# - dropout moderat
# - dense layer sedikit lebih besar
# - learning rate lebih kecil agar training lebih stabil

# %%
# ============================================================
# BLOK 3 - MENCARI FILE DATASET DI /kaggle/input
# ============================================================

ROOT_INPUT = Path("/kaggle/input")

def search_candidate_csv():
    if not ROOT_INPUT.exists():
        raise FileNotFoundError("Folder /kaggle/input tidak ditemukan.")

    candidates = []
    for p in ROOT_INPUT.rglob("*.csv"):
        name = p.name.lower()
        if (
            "epileptic" in name
            or "seizure" in name
            or name == "data.csv"
            or name == "epileptic_seizure_data.csv"
        ):
            candidates.append(p)

    if not candidates:
        all_csv = list(ROOT_INPUT.rglob("*.csv"))
        if not all_csv:
            raise FileNotFoundError("Tidak ada file CSV yang ditemukan di /kaggle/input.")
        candidates = all_csv

    candidates = sorted(candidates, key=lambda x: (len(str(x)), str(x)))
    return candidates

candidate_files = search_candidate_csv()
for i, p in enumerate(candidate_files[:20]):
    print(f"[{i}] {p}")

data_path = candidate_files[0]
print("\nFile terpilih:", data_path)
# Out:
# [0] /kaggle/input/datasets/yasserhessein/epileptic-seizure-recognition/Epileptic Seizure Recognition.csv
#
# File terpilih: /kaggle/input/datasets/yasserhessein/epileptic-seizure-recognition/Epileptic Seizure Recognition.csv

# %% [markdown]
# ## Blok 3
#
# Pencarian file dibuat otomatis di `/kaggle/input` agar tetap fleksibel saat dataset ditambahkan ke notebook. Prioritas diarahkan ke file CSV yang mengandung kata **epileptic** atau **seizure**.

# %%
# ============================================================
# BLOK 4 - MEMBACA DATASET
# ============================================================

df = pd.read_csv(data_path)

print("Shape awal:", df.shape)
display(df.head())
print("\nNama kolom:")
print(df.columns.tolist()[:10], "...", df.columns.tolist()[-10:])
# Out:
# Shape awal: (11500, 180)
#       Unnamed   X1   X2   X3   X4   X5   X6   X7   X8   X9  ...  X170  X171  \
# 0  X21.V1.791  135  190  229  223  192  125   55   -9  -33  ...   -17   -15
# 1  X15.V1.924  386  382  356  331  320  315  307  272  244  ...   164   150
# 2     X8.V1.1  -32  -39  -47  -37  -32  -36  -57  -73  -85  ...    57    64
# 3   X16.V1.60 -105 -101  -96  -92  -89  -95 -102 -100  -87  ...   -82   -81
# 4   X20.V1.54   -9  -65  -98 -102  -78  -48  -16    0  -21  ...     4     2
#
#    X172  X173  X174  X175  X176  X177  X178  y
# 0   -31   -77  -103  -127  -116   -83   -51  4
# 1   146   152   157   156   154   143   129  1
# 2    48    19   -12   -30   -35   -35   -36  5
# 3   -80   -77   -85   -77   -72   -69   -65  5
# 4   -12   -32   -41   -65   -83   -89   -73  5
#
# [5 rows x 180 columns]
# Nama kolom:
# ['Unnamed', 'X1', 'X2', 'X3', 'X4', 'X5', 'X6', 'X7', 'X8', 'X9'] ... ['X170', 'X171', 'X172', 'X173', 'X174', 'X175', 'X176', 'X177', 'X178', 'y']

# %% [markdown]
# ## Blok 4
#
# Dataset dibaca dari satu file CSV utama. Pengecekan awal dilakukan untuk melihat bentuk tabel, nama kolom, dan struktur umum data.

# %%
# ============================================================
# BLOK 5 - MEMBERSIHKAN STRUKTUR KOLOM
# ============================================================

df = df.copy()

# Hapus kolom indeks tambahan jika ada
first_col = str(df.columns[0]).lower()
if "unnamed" in first_col:
    df = df.drop(columns=df.columns[0])

# Pastikan kolom target ditemukan
target_col = None
for col in df.columns:
    col_lower = str(col).lower()
    if col_lower == "y" or col_lower == "label" or col_lower == "target":
        target_col = col
        break

if target_col is None:
    target_col = df.columns[-1]

feature_cols = [c for c in df.columns if c != target_col]

# Pastikan fitur numerik
for col in feature_cols:
    df[col] = pd.to_numeric(df[col], errors="coerce")

df[target_col] = pd.to_numeric(df[target_col], errors="coerce")
df = df.dropna().reset_index(drop=True)

print("Target column:", target_col)
print("Jumlah fitur :", len(feature_cols))
print("Shape bersih :", df.shape)
# Out:
# Target column: y
# Jumlah fitur : 178
# Shape bersih : (11500, 179)

# %% [markdown]
# ## Blok 5
#
# Kolom indeks tambahan dibuang bila ada. Seluruh fitur diubah ke numerik agar rangkaian sinyal dapat diproses langsung sebagai sequence.

# %%
# ============================================================
# BLOK 6 - MEMISAHKAN FITUR DAN LABEL
# ============================================================

X = df[feature_cols].to_numpy(dtype="float32")
y = df[target_col].to_numpy()

print("Shape fitur :", X.shape)
print("Shape target:", y.shape)
print("Label unik  :", np.unique(y))
# Out:
# Shape fitur : (11500, 178)
# Shape target: (11500,)
# Label unik  : [1 2 3 4 5]

# %% [markdown]
# ## Blok 6
#
# Setiap baris merepresentasikan satu segmen sinyal EEG. Fitur berisi deret nilai sinyal, sedangkan kolom target berisi kelas aktivitas otak.

# %%
# ============================================================
# BLOK 7 - CEK DISTRIBUSI KELAS
# ============================================================

class_dist = pd.Series(y).value_counts().sort_index()
dist_df = class_dist.reset_index()
dist_df.columns = ["label", "jumlah_sampel"]

display(dist_df)

plt.figure(figsize=(8, 4))
sns.barplot(data=dist_df, x="label", y="jumlah_sampel")
plt.title("Distribusi Kelas")
plt.xlabel("Label")
plt.ylabel("Jumlah Sampel")
plt.show()
# Out:
#    label  jumlah_sampel
# 0      1           2300
# 1      2           2300
# 2      3           2300
# 3      4           2300
# 4      5           2300

# %% [markdown]
# ## Blok 7
#
# Distribusi kelas dilihat lebih dulu untuk memastikan proporsi data antarkelas. Tahap ini membantu membaca hasil evaluasi sejak awal.

# %%
# ============================================================
# BLOK 8 - ENCODE LABEL MENJADI 0 SAMPAI N-1
# ============================================================

label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

class_names = [str(c) for c in label_encoder.classes_]
num_classes = len(class_names)

print("Class names :", class_names)
print("Jumlah kelas:", num_classes)
# Out:
# Class names : ['1', '2', '3', '4', '5']
# Jumlah kelas: 5

# %% [markdown]
# ## Blok 8
#
# Label diubah ke format numerik berurutan agar sesuai untuk `SparseCategoricalCrossentropy`. Indeks target menjadi lebih rapi tanpa mengubah urutan kelas asli.

# %%
# ============================================================
# BLOK 9 - TRAIN / VALIDATION / TEST SPLIT
# ============================================================

X_trainval, X_test, y_trainval, y_test = train_test_split(
    X,
    y_encoded,
    test_size=TEST_SIZE,
    random_state=SEED,
    stratify=y_encoded
)

val_ratio_adjusted = VAL_SIZE / (1 - TEST_SIZE)

X_train, X_val, y_train, y_val = train_test_split(
    X_trainval,
    y_trainval,
    test_size=val_ratio_adjusted,
    random_state=SEED,
    stratify=y_trainval
)

print("Train shape:", X_train.shape, y_train.shape)
print("Val shape  :", X_val.shape, y_val.shape)
print("Test shape :", X_test.shape, y_test.shape)
# Out:
# Train shape: (8050, 178) (8050,)
# Val shape  : (1725, 178) (1725,)
# Test shape : (1725, 178) (1725,)

# %% [markdown]
# ## Blok 9
#
# Data dibagi menjadi train, validation, dan test dengan **stratify** agar proporsi kelas tetap terjaga pada setiap subset.

# %%
# ============================================================
# BLOK 10 - NORMALISASI PER SAMPEL
# ============================================================

def rowwise_zscore(arr):
    arr = arr.astype("float32")
    mean = arr.mean(axis=1, keepdims=True)
    std = arr.std(axis=1, keepdims=True)
    std = np.where(std < 1e-8, 1.0, std)
    out = (arr - mean) / std
    out = np.clip(out, -5.0, 5.0)
    return out.astype("float32")

X_train_norm = rowwise_zscore(X_train)
X_val_norm   = rowwise_zscore(X_val)
X_test_norm  = rowwise_zscore(X_test)

print("Shape train normalized:", X_train_norm.shape)
print("Contoh mean/std train sample:",
      round(float(X_train_norm[0].mean()), 4),
      round(float(X_train_norm[0].std()), 4))
# Out:
# Shape train normalized: (8050, 178)
# Contoh mean/std train sample: 0.0 1.0

# %% [markdown]
# ## Blok 10
#
# Normalisasi dilakukan **per sampel** agar pola bentuk gelombang tiap segmen lebih menonjol dibandingkan perbedaan skala absolut antarsegmen.

# %%
# ============================================================
# BLOK 11 - BENTUK ULANG MENJADI TENSOR SEQUENCE
# ============================================================

sequence_length = X_train_norm.shape[1]

X_train_seq = X_train_norm.reshape(-1, sequence_length, 1)
X_val_seq   = X_val_norm.reshape(-1, sequence_length, 1)
X_test_seq  = X_test_norm.reshape(-1, sequence_length, 1)

y_train_np = np.asarray(y_train).astype("int32")
y_val_np   = np.asarray(y_val).astype("int32")
y_test_np  = np.asarray(y_test).astype("int32")

print("Train sequence shape:", X_train_seq.shape)
print("Val sequence shape  :", X_val_seq.shape)
print("Test sequence shape :", X_test_seq.shape)
# Out:
# Train sequence shape: (8050, 178, 1)
# Val sequence shape  : (1725, 178, 1)
# Test sequence shape : (1725, 178, 1)

# %% [markdown]
# ## Blok 11
#
# Model RNN menerima input berbentuk `(jumlah_sampel, panjang_sequence, fitur_per_timestep)`. Karena setiap timestep hanya memuat satu nilai sinyal, dimensi terakhir bernilai 1.

# %%
# ============================================================
# BLOK 12 - MEMBUAT TF.DATA PIPELINE
# ============================================================

AUTOTUNE = tf.data.AUTOTUNE

train_ds = (
    tf.data.Dataset.from_tensor_slices((X_train_seq, y_train_np))
    .shuffle(buffer_size=min(len(X_train_seq), 4096), seed=SEED)
    .batch(BATCH_SIZE)
    .prefetch(AUTOTUNE)
)

val_ds = (
    tf.data.Dataset.from_tensor_slices((X_val_seq, y_val_np))
    .batch(BATCH_SIZE)
    .prefetch(AUTOTUNE)
)

test_ds = (
    tf.data.Dataset.from_tensor_slices((X_test_seq, y_test_np))
    .batch(BATCH_SIZE)
    .prefetch(AUTOTUNE)
)
# Out:
# I0000 00:00:1776592385.720046      22 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13757 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1776592385.726297      22 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13757 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5

# %% [markdown]
# ## Blok 12
#
# Pipeline `tf.data` dipakai agar aliran data saat training lebih efisien dan format input tetap konsisten sampai evaluasi.

# %%
# ============================================================
# BLOK 13 - MEMBANGUN ARSITEKTUR RNN
# ============================================================

inputs = layers.Input(shape=(sequence_length, 1), name="input_sequence")

x = layers.Bidirectional(
    layers.SimpleRNN(
        RNN_UNITS_1,
        activation="tanh",
        return_sequences=True,
        dropout=RNN_DROPOUT
    ),
    name="bidir_rnn_1"
)(inputs)

x = layers.Bidirectional(
    layers.SimpleRNN(
        RNN_UNITS_2,
        activation="tanh",
        return_sequences=True,
        dropout=RNN_DROPOUT
    ),
    name="bidir_rnn_2"
)(x)

attn = layers.MultiHeadAttention(
    num_heads=ATTN_HEADS,
    key_dim=ATTN_KEY_DIM,
    dropout=ATTN_DROPOUT,
    name="self_attention"
)(x, x)

x = layers.Add(name="residual_add")([x, attn])
x = layers.LayerNormalization(name="post_attn_norm")(x)

x_avg = layers.GlobalAveragePooling1D(name="gap")(x)
x_max = layers.GlobalMaxPooling1D(name="gmp")(x)
x = layers.Concatenate(name="merge_pool")([x_avg, x_max])

x = layers.Dense(DENSE_UNITS, activation="relu", name="dense_1")(x)
x = layers.Dropout(DENSE_DROPOUT, name="dropout_dense")(x)

outputs = layers.Dense(num_classes, activation="softmax", name="classifier")(x)

model = Model(inputs=inputs, outputs=outputs, name="Enhanced_RNN_Attention")

optimizer = keras.optimizers.Adam(
    learning_rate=LEARNING_RATE,
    clipnorm=1.0
)

model.compile(
    optimizer=optimizer,
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

model.summary()
# Out:
# Model: "Enhanced_RNN_Attention"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_sequence      │ (None, 178, 1)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bidir_rnn_1         │ (None, 178, 256)  │     33,280 │ input_sequence[0… │
# │ (Bidirectional)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bidir_rnn_2         │ (None, 178, 128)  │     41,088 │ bidir_rnn_1[0][0] │
# │ (Bidirectional)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ self_attention      │ (None, 178, 128)  │     66,048 │ bidir_rnn_2[0][0… │
# │ (MultiHeadAttentio… │                   │            │ bidir_rnn_2[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ residual_add (Add)  │ (None, 178, 128)  │          0 │ bidir_rnn_2[0][0… │
# │                     │                   │            │ self_attention[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ post_attn_norm      │ (None, 178, 128)  │        256 │ residual_add[0][… │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gap                 │ (None, 128)       │          0 │ post_attn_norm[0… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gmp                 │ (None, 128)       │          0 │ post_attn_norm[0… │
# │ (GlobalMaxPooling1… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_pool          │ (None, 256)       │          0 │ gap[0][0],        │
# │ (Concatenate)       │                   │            │ gmp[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 128)       │     32,896 │ merge_pool[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_dense       │ (None, 128)       │          0 │ dense_1[0][0]     │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ classifier (Dense)  │ (None, 5)         │        645 │ dropout_dense[0]… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 174,213 (680.52 KB)
#  Trainable params: 174,213 (680.52 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Blok 13
#
# Arsitektur memakai **RNN bertingkat** dengan **arah dua arah** pada vanilla recurrent cell.
# Bagian akhir menggunakan **global average pooling** dan **global max pooling** agar ringkasan urutan tidak hanya bergantung pada timestep terakhir.

# %%
# ============================================================
# BLOK 14 - CALLBACK TRAINING
# ============================================================

checkpoint_path = f"best_{MODEL_NAME.lower()}_epileptic_retry5.keras"

callbacks = [
    EarlyStopping(
        monitor="val_accuracy",
        mode="max",
        patience=8,
        restore_best_weights=True
    ),
    ReduceLROnPlateau(
        monitor="val_loss",
        factor=0.5,
        patience=3,
        min_lr=1e-6
    ),
    ModelCheckpoint(
        filepath=checkpoint_path,
        monitor="val_accuracy",
        mode="max",
        save_best_only=True
    )
]

# %% [markdown]
# ## Blok 14
#
# Callback dipakai untuk menghentikan training saat validation tidak membaik, menurunkan learning rate saat perlu, dan menyimpan bobot terbaik.

# %%
# ============================================================
# BLOK 15 - TRAINING MODEL
# ============================================================

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    callbacks=callbacks,
    verbose=1
)
# Out:
# Epoch 1/40
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1776592395.150137      68 service.cc:152] XLA service 0x2f5819d0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1776592395.150199      68 service.cc:160]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1776592395.150206      68 service.cc:160]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1776592396.645763      68 cuda_dnn.cc:529] Loaded cuDNN version 91002
#   1/126 ━━━━━━━━━━━━━━━━━━━━ 28:37 14s/step - accuracy: 0.1406 - loss: 3.3735
# I0000 00:00:1776592402.359601      68 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 31s 141ms/step - accuracy: 0.3592 - loss: 1.5573 - val_accuracy: 0.5438 - val_loss: 0.9800 - learning_rate: 0.0010
# Epoch 2/40
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 8s 60ms/step - accuracy: 0.5622 - loss: 0.9833 - val_accuracy: 0.6533 - val_loss: 0.7586 - learning_rate: 0.0010
# Epoch 3/40
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 8s 60ms/step - accuracy: 0.6150 - loss: 0.8375 - val_accuracy: 0.6591 - val_loss: 0.7319 - learning_rate: 0.0010
# Epoch 4/40
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 8s 60ms/step - accuracy: 0.6392 - loss: 0.7823 - val_accuracy: 0.6701 - val_loss: 0.7434 - learning_rate: 0.0010
# Epoch 5/40
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 8s 60ms/step - accuracy: 0.6719 - loss: 0.7335 - val_accuracy: 0.6788 - val_loss: 0.7018 - learning_rate: 0.0010
# Epoch 6/40
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 7s 59ms/step - accuracy: 0.6677 - loss: 0.7120 - val_accuracy: 0.6736 - val_loss: 0.7672 - learning_rate: 0.0010
# Epoch 7/40
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 8s 60ms/step - accuracy: 0.6443 - loss: 0.7667 - val_accuracy: 0.7090 - val_loss: 0.6874 - learning_rate: 0.0010
# Epoch 8/40
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 7s 59ms/step - accuracy: 0.6971 - loss: 0.6758 - val_accuracy: 0.6980 - val_loss: 0.6629 - learning_rate: 0.0010
# Epoch 9/40
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 7s 59ms/step - accuracy: 0.6817 - loss: 0.6851 - val_accuracy: 0.6922 - val_loss: 0.6699 - learning_rate: 0.0010
# Epoch 10/40
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 8s 60ms/step - accuracy: 0.6908 - loss: 0.6573 - val_accuracy: 0.7101 - val_loss: 0.6309 - learning_rate: 0.0010
# Epoch 11/40
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 7s 59ms/step - accuracy: 0.6934 - loss: 0.6578 - val_accuracy: 0.6800 - val_loss: 0.6997 - learning_rate: 0.0010
# Epoch 12/40
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 8s 60ms/step - accuracy: 0.7123 - loss: 0.6327 - val_accuracy: 0.7136 - val_loss: 0.6150 - learning_rate: 0.0010
# Epoch 13/40
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 7s 59ms/step - accuracy: 0.7206 - loss: 0.6108 - val_accuracy: 0.7003 - val_loss: 0.6860 - learning_rate: 0.0010
# Epoch 14/40
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 8s 60ms/step - accuracy: 0.7068 - loss: 0.6425 - val_accuracy: 0.7275 - val_loss: 0.6495 - learning_rate: 0.0010
# Epoch 15/40
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 7s 59ms/step - accuracy: 0.7183 - loss: 0.6067 - val_accuracy: 0.7032 - val_loss: 0.6647 - learning_rate: 0.0010
# Epoch 16/40
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 8s 60ms/step - accuracy: 0.7324 - loss: 0.5771 - val_accuracy: 0.7501 - val_loss: 0.5604 - learning_rate: 5.0000e-04
# Epoch 17/40
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 7s 59ms/step - accuracy: 0.7562 - loss: 0.5256 - val_accuracy: 0.7461 - val_loss: 0.5688 - learning_rate: 5.0000e-04
# Epoch 18/40
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 8s 60ms/step - accuracy: 0.7500 - loss: 0.5402 - val_accuracy: 0.7536 - val_loss: 0.5522 - learning_rate: 5.0000e-04
# Epoch 19/40
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 7s 59ms/step - accuracy: 0.7631 - loss: 0.5139 - val_accuracy: 0.7496 - val_loss: 0.5709 - learning_rate: 5.0000e-04
# Epoch 20/40
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 7s 59ms/step - accuracy: 0.7633 - loss: 0.5276 - val_accuracy: 0.7467 - val_loss: 0.5594 - learning_rate: 5.0000e-04
# Epoch 21/40
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 7s 59ms/step - accuracy: 0.7809 - loss: 0.4927 - val_accuracy: 0.7362 - val_loss: 0.5948 - learning_rate: 5.0000e-04
# Epoch 22/40
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 8s 60ms/step - accuracy: 0.7854 - loss: 0.4734 - val_accuracy: 0.7588 - val_loss: 0.5439 - learning_rate: 2.5000e-04
# Epoch 23/40
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 8s 60ms/step - accuracy: 0.8023 - loss: 0.4474 - val_accuracy: 0.7641 - val_loss: 0.5500 - learning_rate: 2.5000e-04
# Epoch 24/40
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 8s 60ms/step - accuracy: 0.8014 - loss: 0.4366 - val_accuracy: 0.7710 - val_loss: 0.5430 - learning_rate: 2.5000e-04
# Epoch 25/40
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 7s 59ms/step - accuracy: 0.8171 - loss: 0.4170 - val_accuracy: 0.7675 - val_loss: 0.5529 - learning_rate: 2.5000e-04
# Epoch 26/40
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 8s 60ms/step - accuracy: 0.8295 - loss: 0.3929 - val_accuracy: 0.7641 - val_loss: 0.5622 - learning_rate: 2.5000e-04
# Epoch 27/40
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 8s 60ms/step - accuracy: 0.8315 - loss: 0.3886 - val_accuracy: 0.7704 - val_loss: 0.5402 - learning_rate: 2.5000e-04
# Epoch 28/40
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 8s 60ms/step - accuracy: 0.8389 - loss: 0.3764 - val_accuracy: 0.7699 - val_loss: 0.5456 - learning_rate: 2.5000e-04
# Epoch 29/40
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 8s 60ms/step - accuracy: 0.8427 - loss: 0.3709 - val_accuracy: 0.7646 - val_loss: 0.5527 - learning_rate: 2.5000e-04
# Epoch 30/40
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 8s 60ms/step - accuracy: 0.8499 - loss: 0.3598 - val_accuracy: 0.7693 - val_loss: 0.5509 - learning_rate: 2.5000e-04
# Epoch 31/40
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 8s 60ms/step - accuracy: 0.8609 - loss: 0.3277 - val_accuracy: 0.7797 - val_loss: 0.5461 - learning_rate: 1.2500e-04
# Epoch 32/40
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 8s 60ms/step - accuracy: 0.8696 - loss: 0.3135 - val_accuracy: 0.7733 - val_loss: 0.5719 - learning_rate: 1.2500e-04
# Epoch 33/40
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 7s 59ms/step - accuracy: 0.8692 - loss: 0.3005 - val_accuracy: 0.7704 - val_loss: 0.5777 - learning_rate: 1.2500e-04
# Epoch 34/40
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 8s 60ms/step - accuracy: 0.8947 - loss: 0.2792 - val_accuracy: 0.7809 - val_loss: 0.5633 - learning_rate: 6.2500e-05
# Epoch 35/40
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 7s 59ms/step - accuracy: 0.8999 - loss: 0.2606 - val_accuracy: 0.7768 - val_loss: 0.5792 - learning_rate: 6.2500e-05
# Epoch 36/40
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 7s 59ms/step - accuracy: 0.8924 - loss: 0.2751 - val_accuracy: 0.7739 - val_loss: 0.5820 - learning_rate: 6.2500e-05
# Epoch 37/40
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 8s 60ms/step - accuracy: 0.9064 - loss: 0.2504 - val_accuracy: 0.7814 - val_loss: 0.5808 - learning_rate: 3.1250e-05
# Epoch 38/40
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 8s 60ms/step - accuracy: 0.9022 - loss: 0.2503 - val_accuracy: 0.7803 - val_loss: 0.5843 - learning_rate: 3.1250e-05
# Epoch 39/40
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 8s 60ms/step - accuracy: 0.9083 - loss: 0.2430 - val_accuracy: 0.7803 - val_loss: 0.5832 - learning_rate: 3.1250e-05
# Epoch 40/40
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 7s 59ms/step - accuracy: 0.9037 - loss: 0.2560 - val_accuracy: 0.7797 - val_loss: 0.5910 - learning_rate: 1.5625e-05

# %% [markdown]
# ## Blok 15
#
# Training dilakukan pada data train dan dipantau menggunakan validation set. Riwayat training disimpan untuk melihat perubahan loss dan accuracy antarepoch.

# %%
# ============================================================
# BLOK 16 - VISUALISASI LEARNING CURVE
# ============================================================

history_df = pd.DataFrame(history.history)

plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history_df["loss"], label="train_loss")
plt.plot(history_df["val_loss"], label="val_loss")
plt.title("Loss Curve")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history_df["accuracy"], label="train_accuracy")
plt.plot(history_df["val_accuracy"], label="val_accuracy")
plt.title("Accuracy Curve")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Blok 16
#
# Kurva training membantu membaca apakah model mulai stabil, underfitting, atau overfitting.

# %%
# ============================================================
# BLOK 17 - PREDIKSI PADA DATA TEST
# ============================================================

test_loss, test_accuracy = model.evaluate(test_ds, verbose=0)

y_proba = model.predict(test_ds, verbose=0)
y_pred = np.argmax(y_proba, axis=1)

print("Test loss     :", round(float(test_loss), 6))
print("Test accuracy :", round(float(test_accuracy), 6))
# Out:
# Test loss     : 0.562143
# Test accuracy : 0.773333

# %% [markdown]
# ## Blok 17
#
# Prediksi probabilitas pada data test diubah menjadi label akhir dengan `argmax`. Tahap ini menghasilkan output utama yang dipakai pada metrik evaluasi.

# %%
# ============================================================
# BLOK 18 - MENGHITUNG METRIK EVALUASI
# ============================================================

metrics_dict = {
    "accuracy": accuracy_score(y_test_np, y_pred),
    "balanced_accuracy": balanced_accuracy_score(y_test_np, y_pred),
    "precision_macro": precision_score(y_test_np, y_pred, average="macro", zero_division=0),
    "recall_macro": recall_score(y_test_np, y_pred, average="macro", zero_division=0),
    "f1_macro": f1_score(y_test_np, y_pred, average="macro", zero_division=0),
    "precision_weighted": precision_score(y_test_np, y_pred, average="weighted", zero_division=0),
    "recall_weighted": recall_score(y_test_np, y_pred, average="weighted", zero_division=0),
    "f1_weighted": f1_score(y_test_np, y_pred, average="weighted", zero_division=0),
    "roc_auc_ovr_macro": None,
    "roc_auc_ovr_weighted": None,
}

try:
    metrics_dict["roc_auc_ovr_macro"] = roc_auc_score(
        y_test_np, y_proba, multi_class="ovr", average="macro"
    )
    metrics_dict["roc_auc_ovr_weighted"] = roc_auc_score(
        y_test_np, y_proba, multi_class="ovr", average="weighted"
    )
except Exception as e:
    print("ROC-AUC tidak dapat dihitung:", e)

for k, v in metrics_dict.items():
    print(f"{k:22s}: {None if v is None else round(float(v), 6)}")
# Out:
# accuracy              : 0.773333
# balanced_accuracy     : 0.773333
# precision_macro       : 0.774573
# recall_macro          : 0.773333
# f1_macro              : 0.773065
# precision_weighted    : 0.774573
# recall_weighted       : 0.773333
# f1_weighted           : 0.773065
# roc_auc_ovr_macro     : 0.955288
# roc_auc_ovr_weighted  : 0.955288

# %% [markdown]
# ## Blok 18
#
# Metrik evaluasi.
#
# Metrik utama yang dicatat:
# - accuracy
# - balanced accuracy
# - precision
# - recall
# - f1-score
# - ROC-AUC multiclass
# - test loss

# %%
# ============================================================
# BLOK 19 - CLASSIFICATION REPORT
# ============================================================

report = classification_report(
    y_test_np,
    y_pred,
    target_names=class_names,
    digits=4,
    zero_division=0
)

print(report)
# Out:
#               precision    recall  f1-score   support
#
#            1     0.9792    0.9536    0.9662       345
#            2     0.7003    0.6232    0.6595       345
#            3     0.6649    0.7246    0.6935       345
#            4     0.7814    0.8290    0.8045       345
#            5     0.7471    0.7362    0.7416       345
#
#     accuracy                         0.7733      1725
#    macro avg     0.7746    0.7733    0.7731      1725
# weighted avg     0.7746    0.7733    0.7731      1725

# %% [markdown]
# ## Blok 19
#
# Classification report untuk melihat performa tiap kelas secara detail.

# %%
# ============================================================
# BLOK 20 - CONFUSION MATRIX
# ============================================================

cm = confusion_matrix(y_test_np, y_pred)

plt.figure(figsize=(7, 6))
sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=class_names,
    yticklabels=class_names
)
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %% [markdown]
# ## Blok 20
#
# Confusion matrix menunjukkan pola prediksi benar dan salah pada setiap kelas sehingga kelas yang sering tertukar bisa terlihat lebih jelas.

# %%
# ============================================================
# BLOK 21 - MENYIMPAN HASIL RINGKAS
# ============================================================

results_path = f"results_{MODEL_NAME.lower()}_epileptic_retry.json"

serializable_results = {
    "model": MODEL_NAME,
    "class_names": class_names,
    "metrics": {
        k: (None if v is None else float(v))
        for k, v in metrics_dict.items()
    },
    "test_loss": float(test_loss),
    "test_accuracy": float(test_accuracy)
}

with open(results_path, "w") as f:
    json.dump(serializable_results, f, indent=2)

print(f"Hasil ringkas disimpan di: {results_path}")
# Out:
# Hasil ringkas disimpan di: results_rnn_epileptic_retry.json

# %% [markdown]
# ## Blok 21
#
# Hasil evaluasi disimpan ke file JSON agar mudah dipakai kembali saat membuat tabel perbandingan antarmodel.
